# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os   

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
raw_data=pd.read_csv('/kaggle/input/playground-series-s4e7/train.csv')
df=raw_data.copy()
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
df.describe()
# Out:
#                  id           Age  Driving_License   Region_Code  \
# count  1.150480e+07  1.150480e+07     1.150480e+07  1.150480e+07
# mean   5.752398e+06  3.838356e+01     9.980220e-01  2.641869e+01
# std    3.321149e+06  1.499346e+01     4.443120e-02  1.299159e+01
# min    0.000000e+00  2.000000e+01     0.000000e+00  0.000000e+00
# 25%    2.876199e+06  2.400000e+01     1.000000e+00  1.500000e+01
# 50%    5.752398e+06  3.600000e+01     1.000000e+00  2.800000e+01
# 75%    8.628598e+06  4.900000e+01     1.000000e+00  3.500000e+01
# max    1.150480e+07  8.500000e+01     1.000000e+00  5.200000e+01
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel       Vintage  \
# count        1.150480e+07    1.150480e+07          1.150480e+07  1.150480e+07
# mean         4.629966e-01    3.046137e+04          1.124254e+02  1.638977e+02
# std          4.986289e-01    1.645475e+04          5.403571e+01  7.997953e+01
# min          0.000000e+00    2.630000e+03          1.000000e+00  1.000000e+01
# 25%          0.000000e+00    2.527700e+04          2.900000e+01  9.900000e+01
# 50%          0.000000e+00    3.182400e+04          1.510000e+02  1.660000e+02
# 75%          1.000000e+00    3.945100e+04          1.520000e+02  2.320000e+02
# max          1.000000e+00    5.401650e+05          1.630000e+02  2.990000e+02
#
#            Response
# count  1.150480e+07
# mean   1.229973e-01
# std    3.284341e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11504798 entries, 0 to 11504797
# Data columns (total 12 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   id                    int64
#  1   Gender                object
#  2   Age                   int64
#  3   Driving_License       int64
#  4   Region_Code           float64
#  5   Previously_Insured    int64
#  6   Vehicle_Age           object
#  7   Vehicle_Damage        object
#  8   Annual_Premium        float64
#  9   Policy_Sales_Channel  float64
#  10  Vintage               int64
#  11  Response              int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 1.0+ GB

# %% [markdown]
# <h1>Check for Null and duplicated Values</h1>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %% [markdown]
# There are no null values

# %% [markdown]
# <h1>Exploratory Data Analysis(EDA)</h1>

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# There are only two genders

# %%
batch_size = 1000000
num_batches = len(df) // batch_size + (1 if len(df) % batch_size != 0 else 0)
for i in range(num_batches):
    start = i * batch_size
    end = start + batch_size
    batch = df[start:end]
    gender_counts = batch['Gender'].value_counts()
    plt.bar(gender_counts.index, gender_counts.values, color='maroon')
    plt.xlabel("Gender")
    plt.ylabel("Count")
    plt.title(f"Distribution of Gender (Batch {i + 1})")
    plt.show()

# %% [markdown]
# The Graphs above tells us about the distribution of males and females in our dataset. We used batches to prevent load on the cpu

# %%
bins = [0, 18, 30, 65, float('inf')] 
labels = ['<18', '18-30', '31-65', '>65']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
age_group_counts = df['Age Group'].value_counts().sort_index()
plt.bar(age_group_counts.index, age_group_counts.values, color='maroon')
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("Distribution of Age Groups")
for index, value in enumerate(age_group_counts.values):
    plt.text(index, value + 1, str(value), ha='center')
plt.show()

# %% [markdown]
# We used data aggregation and group People based on their age groups.The Bar graph showing distribution of various age groups

# %%
df['Driving_License'].unique()
# Out:
# array([1, 0])

# %%
driving_license_counts = df[df['Driving_License'] == 1].groupby('Gender').size().reset_index(name='Count')
sns.barplot(x='Gender', y='Count', data=driving_license_counts, palette='pastel')
plt.xlabel('Gender')
plt.ylabel('Number of People with Driving License')
plt.title('Number of Males and Females with a Driving License')
for index, value in enumerate(driving_license_counts['Count']):
    plt.text(index, value + 1, str(value), ha='center')
plt.show()

# %% [markdown]
# From the above graph we found total 11,482,041 out of 11504798 people have driving license out of which 5270990 are males and 6211051 are females

# %%
insurance_count = df['Previously_Insured'].value_counts()
plt.figure(figsize=(8, 5))
insurance_count.plot(kind='bar', color=['red', 'green'])
plt.title('Insurance Status of Vehicle Owners')
plt.xlabel('Previously Insurance Done')
plt.ylabel('Number of People')
for index, value in enumerate(insurance_count):
    plt.text(index, value + 1, str(value), ha='center')
plt.xticks([0, 1], labels=['No Previous Insurance ', 'Previous Insurance'],rotation=0)
plt.show()

# %% [markdown]
# From the above bar plot it is clear that a total of 5326682 got their vehicle previously insuranced

# %%
grouped_data = df.groupby(['Driving_License', 'Previously_Insured']).size().unstack(fill_value=0)
grouped_data.plot(kind='bar', stacked=True, color=['red', 'green'], figsize=(8, 5))
plt.title('Driving License vs. Previously Insurance of Vehicle')
plt.xlabel('Driving License')
plt.ylabel('Number of People')
plt.xticks(ticks=[0, 1], labels=['No License', 'Has License'], rotation=0)
plt.legend(['No Insurance', 'Has Insurance'])
plt.show()

# %% [markdown]
# From the above stacked graph it is clear that no peron without license got insurance but yeah their are people who got driving license but ditn't have any insurance

# %%
contingency_table = pd.crosstab(df['Driving_License'], df['Previously_Insured'], margins=True)
plt.figure(figsize=(8, 6))
sns.heatmap(contingency_table.iloc[:-1, :-1], annot=True, cmap="YlGnBu", fmt='d')
plt.title('Relationship Between Driving License and Previously Insurance of Vehicle')
plt.xlabel('Previously Insurance of Vehicle (0 = No, 1 = Yes)')
plt.ylabel('Driving License (0 = No, 1 = Yes)')
plt.show()
print(f'\t Insights of the contingency table\n{contingency_table}')
# Out:
# 	 Insights of the contingency table
# Previously_Insured        0        1       All
# Driving_License
# 0                     15721     7036     22757
# 1                   6162395  5319646  11482041
# All                 6178116  5326682  11504798

# %% [markdown]
# Total  of 22,757 peope with no driving license out of which 15,721 got no previous insurance. 11,482,041 have driving license out of which 6,162,395 got no previous insurance

# %%
newdf=df[['Driving_License','Previously_Insured','Age Group','Vehicle_Age']].copy()
newdf.head()
# Out:
#    Driving_License  Previously_Insured Age Group Vehicle_Age
# 0                1                   0     18-30    1-2 Year
# 1                1                   0     31-65   > 2 Years
# 2                1                   1     18-30    < 1 Year
# 3                1                   0     31-65    1-2 Year
# 4                1                   1     31-65    1-2 Year

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='Age Group', hue='Vehicle_Age', data=newdf,palette='Set2')
plt.title('Distribution of Vehicle Age Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Vehicle Age')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Younger person Between age group of 18-30 tends to have new latest model and adult age group tends to use vehivle not neither new nor old  vehicles. Whereas old people hardly drives and if yes they drive old model or same as that of adult age people

# %%
driving_license_gender = df[df['Driving_License'] == 1].groupby('Age Group').size().reset_index(name='Count')
sns.barplot(x='Age Group', y='Count', data=driving_license_gender, palette='pastel')
plt.xlabel('Age Group')
plt.ylabel('Number of People with Driving License')
plt.title('Number of people of different with a Driving License')
for index, value in enumerate(driving_license_counts['Count']):
    plt.text(index, value + 1, str(value), ha='center')
plt.show()
# Out:
# /tmp/ipykernel_36/493544295.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   driving_license_gender = df[df['Driving_License'] == 1].groupby('Age Group').size().reset_index(name='Count')
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %% [markdown]
# Above distribution showing  people of different age groups having license middle adult age tends to have maximum driving license followed by new youth and old age

# %%
aggregated_data = newdf.groupby(['Driving_License', 'Age Group', 'Vehicle_Age']).size().reset_index(name='Count')
plt.figure(figsize=(10, 6))
sns.catplot(x='Age Group', y='Count', hue='Vehicle_Age', data=aggregated_data, palette='Set2')
plt.title('Vehicle Age Distribution by Age Group and Driving License Status')
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.legend(title='Vehicle Age')
plt.show()
# Out:
# /tmp/ipykernel_36/1630626878.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   aggregated_data = newdf.groupby(['Driving_License', 'Age Group', 'Vehicle_Age']).size().reset_index(name='Count')
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# Aggregated Catplot of Age Group Count and Vehicle Age

# %%
damage = newdf['Vehicle_Damage'].value_counts()
plt.figure(figsize=(8, 5))
damage.plot(kind='bar', color=['yellow','blue'])
plt.title('Vehicle Status')
plt.xlabel('Damaged Vehicle')
plt.ylabel('Number of Vehicle')
for index, value in enumerate(damage):
    plt.text(index, value + 1, str(value), ha='center')
plt.xticks(rotation=1)
plt.show()

# %% [markdown]
#  The above bar plot shows vehicle is damage or not

# %%
grouped_data = newdf.groupby(['Previously_Insured','Vehicle_Damage']).size().unstack(fill_value=0)
grouped_data.plot(kind='bar', stacked=True, color=['pink', 'purple'], figsize=(8, 5))
plt.title('Vehicle Status vs. Previously Insurance of Vehicle')
plt.xlabel('Previously_Insured')
plt.ylabel('Number of Vehicle')
plt.xticks(rotation=0)
plt.legend(['No Damage', 'Damage'])
plt.show()

# %% [markdown]
# The above barplot shows that mostly vehicles with no insurance are damge

# %%
grouped_data = newdf.groupby(['Previously_Insured', 'Vehicle_Damage', 'Age Group']).size().reset_index(name='Count')
fig, ax = plt.subplots(figsize=(8, 6))
for (prev_ins, age_group), group in grouped_data.groupby(['Previously_Insured', 'Age Group']):
    ax.bar(
        group['Vehicle_Damage'],
        group['Count'],
        label=f'Prev_Insured={prev_ins}, Age Group={age_group}',
        width=0.4
    )
ax.set_xlabel('Vehicle Damage')
ax.set_ylabel('Count')
ax.set_title('Count of Previously Insured vs Vehicle Damage by Age Group')
ax.legend(title='Categories')
plt.show()
# Out:
# /tmp/ipykernel_36/3446162666.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_data = newdf.groupby(['Previously_Insured', 'Vehicle_Damage', 'Age Group']).size().reset_index(name='Count')
# /tmp/ipykernel_36/3446162666.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   for (prev_ins, age_group), group in grouped_data.groupby(['Previously_Insured', 'Age Group']):

# %% [markdown]
# From the above plot it is clear that there most vehcles are famged by age group 31-65 with no previous insurance

# %%
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response Age Group
# 0         0     18-30
# 1         1     31-65
# 2         0     18-30
# 3         0     31-65
# 4         0     31-65

# %%
newdf =df[['Previously_Insured','Annual_Premium']].copy()
newdf.head()
# Out:
#    Previously_Insured  Annual_Premium
# 0                   0         65101.0
# 1                   0         58911.0
# 2                   1         38043.0
# 3                   0          2630.0
# 4                   1         31951.0

# %%
# Calculate descriptive statistics
mean_premium = newdf.groupby('Previously_Insured')['Annual_Premium'].mean()
median_premium = newdf.groupby('Previously_Insured')['Annual_Premium'].median()

print("Mean Annual Premium:")
print(mean_premium)
print("\nMedian Annual Premium:")
print(median_premium)

# Visualization: Bar plot for mean premiums
plt.figure(figsize=(8, 6))
newdf.groupby('Previously_Insured')['Annual_Premium'].mean().plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Previously Insured (0 = No, 1 = Yes)')
plt.ylabel('Average Annual Premium')
plt.title('Average Annual Premium Based on Previous Insurance Status')
plt.xticks([0, 1], ['No', 'Yes'], rotation=0)
plt.show()

# Visualization: Box plot for premium distribution
plt.figure(figsize=(8, 6))
newdf.boxplot(column='Annual_Premium', by='Previously_Insured', grid=False)
plt.title('Distribution of Annual Premiums Based on Previous Insurance Status')
plt.suptitle('')  # Remove default suptitle
plt.xlabel('Previously Insured (0 = No, 1 = Yes)')
plt.ylabel('Annual Premium')
plt.xticks([1, 2], ['No', 'Yes'])
plt.show()
# Out:
# Mean Annual Premium:
# Previously_Insured
# 0    30344.258237
# 1    30597.202171
# Name: Annual_Premium, dtype: float64
#
# Median Annual Premium:
# Previously_Insured
# 0    32768.0
# 1    31031.0
# Name: Annual_Premium, dtype: float64

# %% [markdown]
# The above plot shows that there are some people who give annual premium but got no insurance which implies that those hav'e given their premium therefor their insurancce wasn't active

# %%
grouped_data = df.groupby('Policy_Sales_Channel').agg(
    Average_Premium=('Annual_Premium', 'mean'),
    Count_Previously_Insured=('Previously_Insured', 'sum')
).reset_index()

# Plot average premium by sales channel
plt.figure(figsize=(10, 6))
plt.bar(grouped_data['Policy_Sales_Channel'], grouped_data['Average_Premium'], color='skyblue')
plt.xlabel('Policy Sales Channel')
plt.ylabel('Average Annual Premium')
plt.title('Average Annual Premium by Policy Sales Channel')
plt.xticks(grouped_data['Policy_Sales_Channel'])
plt.show()

# %%
newdf=df[['Region_Code','Policy_Sales_Channel','id']].copy()
newdf.head()
# Out:
#    Region_Code  Policy_Sales_Channel  id
# 0         35.0                 124.0   0
# 1         28.0                  26.0   1
# 2         14.0                 152.0   2
# 3          1.0                 156.0   3
# 4         15.0                 152.0   4

# %%
pivot_table = newdf.groupby(['Region_Code', 'Policy_Sales_Channel']).size().unstack(fill_value=0)
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_table, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Policy Sales Channel')
plt.ylabel('Region Code')
plt.title('Heatmap of Policies Sold per Region and Sales Channel')
plt.show()

# %%
Channel  = newdf['Policy_Sales_Channel'].value_counts()
Channel.plot(kind='bar', color=['yellow','blue'])
plt.title('Count of registerations per channel')
plt.xlabel('Channel Nuber')
plt.ylabel('Count')
for index, value in enumerate(Channel):
    plt.text(index, value + 1, str(value), ha='center')
plt.xticks(rotation=1)
plt.show()

# %% [markdown]
# Above plot is showing count of registrations for each channel.There are totl 152 channels
